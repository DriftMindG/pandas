# %%
import pandas as pd
df = pd.read_csv("aapl.csv",parse_dates=["Date"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22948\1672911111.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("aapl.csv",parse_dates=["Date"])

# %%
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
df.set_index("Date",inplace=True)

# %%
df.loc["2016"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-12-30  116.65  117.20  115.43  115.82  30586265
# 2016-12-29  116.45  117.11  116.40  116.73  15039519
# 2016-12-28  117.52  118.02  116.20  116.76  20905892
# 2016-12-27  116.52  117.80  116.49  117.26  18296855
# 2016-12-23  115.59  116.52  115.59  116.52  14249484
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [122 rows x 5 columns]

# %%
df[["Close","Volume"]][df["Open"]>100]
# Out:
#              Close    Volume
# Date
# 2017-07-07  144.18  19201712
# 2017-07-06  142.73  24128782
# 2017-07-05  144.09  21569557
# 2017-07-03  143.50  14277848
# 2017-06-30  144.02  23024107
# ...            ...       ...
# 2016-08-02  104.48  33816556
# 2016-08-01  106.05  38167871
# 2016-07-29  104.21  27733688
# 2016-07-28  104.34  39869839
# 2016-07-27  102.95  92344820
#
# [239 rows x 2 columns]

# %%
#alternate
df.loc["2017-07"].Close
# Out:
# Date
# 2017-07-07    144.18
# 2017-07-06    142.73
# 2017-07-05    144.09
# 2017-07-03    143.50
# Name: Close, dtype: float64

# %%
df.loc["2017-07"].Close.mean()
# Out:
# 143.625

# %%
df.sort_index(inplace=True)

# %%
df.loc["2017-07":"2017-12"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712

# %%
df.Close.resample("Q").mean().plot(kind= "bar")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22948\491464919.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample("Q").mean().plot(kind= "bar")
# <Axes: xlabel='Date'>
