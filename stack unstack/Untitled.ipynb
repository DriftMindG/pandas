# %%
import pandas as pd
dp= pd.read_excel("stocks.xlsx",skiprows=1)
dp
# Out:
#      Company  Facebook  Google  Microsoft  Facebook.1  Google.1  Microsoft.1
# 0 2017-06-05       155     955         66       37.10      32.0        30.31
# 1 2017-06-06       150     987         69       36.98      31.3        30.56
# 2 2017-06-07       153     963         62       36.78      31.7        30.46
# 3 2017-06-08       155    1000         61       36.11      31.2        30.11
# 4 2017-06-09       156    1012         66       37.07      30.0        31.00

# %%
z=pd.melt(dp,id_vars=["Company"])

# %%
z[z["variable"]=="Facebook"]
# Out:
#      Company  variable  value
# 0 2017-06-05  Facebook  155.0
# 1 2017-06-06  Facebook  150.0
# 2 2017-06-07  Facebook  153.0
# 3 2017-06-08  Facebook  155.0
# 4 2017-06-09  Facebook  156.0

# %%
df= pd.read_excel("stocks.xlsx",header=[0,1],index_col=[0])
df
# Out:
#               Price                  Price to earnings ratio (P/E)         \
# Company    Facebook Google Microsoft                      Facebook Google
# 2017-06-05      155    955        66                         37.10   32.0
# 2017-06-06      150    987        69                         36.98   31.3
# 2017-06-07      153    963        62                         36.78   31.7
# 2017-06-08      155   1000        61                         36.11   31.2
# 2017-06-09      156   1012        66                         37.07   30.0
#
#
# Company    Microsoft
# 2017-06-05     30.31
# 2017-06-06     30.56
# 2017-06-07     30.46
# 2017-06-08     30.11
# 2017-06-09     31.00

# %%
df.stack()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_33240\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#                       Price  Price to earnings ratio (P/E)
#            Company
# 2017-06-05 Facebook     155                          37.10
#            Google       955                          32.00
#            Microsoft     66                          30.31
# 2017-06-06 Facebook     150                          36.98
#            Google       987                          31.30
#            Microsoft     69                          30.56
# 2017-06-07 Facebook     153                          36.78
#            Google       963                          31.70
#            Microsoft     62                          30.46
# ...

# %%
dff=df.stack(level=0)
dff
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_33240\3219284516.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   dff=df.stack(level=0)
# Company                                   Facebook  Google  Microsoft
# 2017-06-05 Price                            155.00   955.0      66.00
#            Price to earnings ratio (P/E)     37.10    32.0      30.31
# 2017-06-06 Price                            150.00   987.0      69.00
#            Price to earnings ratio (P/E)     36.98    31.3      30.56
# 2017-06-07 Price                            153.00   963.0      62.00
#            Price to earnings ratio (P/E)     36.78    31.7      30.46
# 2017-06-08 Price                            155.00  1000.0      61.00
#            Price to earnings ratio (P/E)     36.11    31.2      30.11
# ...

# %%
dff.unstack()
# Out:
# Company    Facebook                                Google  \
#               Price Price to earnings ratio (P/E)   Price
# 2017-06-05    155.0                         37.10   955.0
# 2017-06-06    150.0                         36.98   987.0
# 2017-06-07    153.0                         36.78   963.0
# 2017-06-08    155.0                         36.11  1000.0
# 2017-06-09    156.0                         37.07  1012.0
#
# Company                                  Microsoft  \
#            Price to earnings ratio (P/E)     Price
# 2017-06-05                          32.0      66.0
# 2017-06-06                          31.3      69.0
# 2017-06-07                          31.7      62.0
# 2017-06-08                          31.2      61.0
# 2017-06-09                          30.0      66.0
#
# Company
#            Price to earnings ratio (P/E)
# 2017-06-05                         30.31
# 2017-06-06                         30.56
# 2017-06-07                         30.46
# ...

# %%
df= pd.read_excel("stocks_3_levels.xlsx",header=[0,1,2],index_col=[0])

# %%
df
# Out:
#         Price Ratios                                                        \
#                Price                  Price to earnings ratio (P/E)
# Company     Facebook Google Microsoft                      Facebook Google
# Q1 2016          155    955        66                         37.10   32.0
# Q2 2016          150    987        69                         36.98   31.3
# Q3 2016          153    963        62                         36.78   31.7
# Q4 2016          155   1000        61                         36.11   31.2
# Q1 2017          156   1012        66                         37.07   30.0
#
#                   Income Statement                                     \
#                          Net Sales                  Net Profit
# Company Microsoft         Facebook Google Microsoft   Facebook Google
# Q1 2016     30.31              2.6     20     18.70       0.80   5.43
# Q2 2016     30.56              3.1     22     21.30       0.97   5.89
# ...

# %%
df.stack()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_33240\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#                   Price Ratios                               Income Statement  \
#                          Price Price to earnings ratio (P/E)        Net Sales
#         Company
# Q1 2016 Facebook           155                         37.10             2.60
#         Google             955                         32.00            20.00
#         Microsoft           66                         30.31            18.70
# Q2 2016 Facebook           150                         36.98             3.10
#         Google             987                         31.30            22.00
#         Microsoft           69                         30.56            21.30
# ...

# %%
df.stack(level=0)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_33240\4116294391.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)
#                             Price                    \
# Company                  Facebook  Google Microsoft
# Q1 2016 Income Statement      NaN     NaN       NaN
#         Price Ratios        155.0   955.0      66.0
# Q2 2016 Income Statement      NaN     NaN       NaN
#         Price Ratios        150.0   987.0      69.0
# Q3 2016 Income Statement      NaN     NaN       NaN
#         Price Ratios        153.0   963.0      62.0
# Q4 2016 Income Statement      NaN     NaN       NaN
#         Price Ratios        155.0  1000.0      61.0
# Q1 2017 Income Statement      NaN     NaN       NaN
#         Price Ratios        156.0  1012.0      66.0
#
# ...
